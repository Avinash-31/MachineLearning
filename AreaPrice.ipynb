# %% [markdown]
# PROJECT 1
# AREA PRICE
# (predicting the price)

# %%
pip install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pandas in d:\coding\ml\project\myenv\lib\site-packages (2.2.2)
# ...
# [notice] A new release of pip available: 22.3 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv("areaPrice.csv")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# area -> independent variable
# price -> real value
# Supervised ML

# %%
x=df[["area"]]

# %%
y=df[["price"]]

# %%
y
# Out:
#     price
# 0  550000
# 1  565000
# 2  610000
# 3  680000
# 4  725000

# %% [markdown]
# data visualisation

# %%
pip install matplotlib
# Out:
# ...
#
# ...
#      ---------------------------------------- 8.0/8.0 MB 877.6 kB/s eta 0:00:00
# ...
#      ------------------------------------ 188.2/188.2 kB 951.6 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.2/2.2 MB 894.5 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 56.1/56.1 kB 1.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 664.0 kB/s eta 0:00:00
# ...
#      ------------------------------------ 103.2/103.2 kB 664.3 kB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
plt.title("Area Vs Price")
plt.xlabel("Area")
plt.ylabel("Price")
plt.scatter(x,y,ec=["red"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 5
#       3 plt.ylabel("Price")
#       4 plt.scatter(x,y,ec=["red"])
# ----> 5 plt.plot(x,pred)
#
# NameError: name 'pred' is not defined

# %%
pip install scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting scikit-learn
# ...
#      ---------------------------------------- 11.0/11.0 MB 3.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 46.2/46.2 MB 1.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 301.8/301.8 kB 3.7 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[5000]])
# Out:
# D:\coding\ML\project\myenv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[859554.79452055]])

# %%
model.coef_
# Out:
# array([[131.73076923]])

# %%
model.intercept_
# Out:
# array([190961.53846154])

# %%
pred = model.predict(x)

# %%
x
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  4000

# %%
y
# Out:
#     price
# 0  550000
# 1  565000
# 2  610000
# 3  725000

# %%
plt.title("Area Vs Price")
plt.xlabel("Area")
plt.ylabel("Price")
plt.scatter(x,y,ec=["red"])
plt.plot(x,pred)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
model.predict(["5500"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 model.predict(["5500"])
#
# File D:\coding\ML\project\myenv\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File D:\coding\ML\project\myenv\Lib\site-packages\sklearn\linear_model\_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# --> 285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#     287     if coef_.ndim == 1:
#
# ...

# %%
model.predict[[5500]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 model.predict[[5500]]
#
# TypeError: 'method' object is not subscriptable

# %%
model.predict([[5500]])
# Out:
# array([[927448.63013699]])

# %%
areaInput = int(input("Enter the value of area to predict the price"))
res = model.predict([[areaInput]])
print(f"Price of the area {areaInput} = {res[0][0]}")
# Out:
# Enter the value of area to predict the price 200
# Price of the area 200 = 207773.97260273967
